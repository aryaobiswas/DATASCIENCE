# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-034689df-f79e-439a-af30-db64d16c93b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-034689df-f79e-439a-af30-db64d16c93b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['IndianFoodDatasetCSV.csv']))
df.sort_values('TotalTimeInMins', ascending=False).head()
# Out:
#        Srno                                         RecipeName  \
# 4288   5703                  Traditional Christmas Cake Recipe
# 934    1030  कवाती रेसिपी - Nepali Beans Soup (Recipe In Hi...
# 4525   6107  भगारा पीठा रेसिपी - Baghara Pitha (Recipe In H...
# 6477  11204  Homemade Quick Puff Pastry Sheet Recipe | Perf...
# 2988   3634     Dairyfree Balsamic Strawberry Ice-cream Recipe
#
#                                    TranslatedRecipeName  \
# 4288                  Traditional Christmas Cake Recipe
# 934          Kavati recipe - Nepali Beans Soup (Recipe)
# 4525              Bhagara Peetha Recipe - Baghara Pitha
# 6477  Homemade Quick Puff Pastry Sheet Recipe | Perf...
# 2988    Dairy Free Balsamic Strawberry Ice-cream Recipe
#
#                                             Ingredients  \
# 4288  3/4 cup Black raisins,1/4 cup Prunes - chopped...
# 934   1/2 कप राजमा,1/2 कप हरी मूंग दाल - पूरी,1/4 कप...
# 4525  1 कप सफेद उरद दाल (split),1 बड़े चमच्च मेथी के ...
# ...

# %%
newdf=df.copy()
newdf=newdf.drop(["RecipeName","Ingredients","Instructions","URL"],axis=1)

# %%
newdf.sort_values('TotalTimeInMins', ascending=False).head()
# Out:
#        Srno                               TranslatedRecipeName  \
# 4288   5703                  Traditional Christmas Cake Recipe
# 934    1030         Kavati recipe - Nepali Beans Soup (Recipe)
# 4525   6107              Bhagara Peetha Recipe - Baghara Pitha
# 6477  11204  Homemade Quick Puff Pastry Sheet Recipe | Perf...
# 2988   3634    Dairy Free Balsamic Strawberry Ice-cream Recipe
#
#                                   TranslatedIngredients  PrepTimeInMins  \
# 4288  3/4 cup Black raisins,1/4 cup Prunes - chopped...            2880
# 934   1/2 cup rajma, 1/2 cup green moong dal - poori...            1440
# 4525  1 कप सफेद उरद दाल (split),1 बड़े चमच्च मेथी के ...            1440
# 6477  315 grams All Purpose Flour (Maida),5 grams Sa...            1440
# 2988  700 grams Strawberries - chopped,1-1/4 cup Cas...             500
#
#       CookTimeInMins  TotalTimeInMins  Servings        Cuisine  \
# 4288              45             2925         1    Continental
# ...

# %%
def is_ascii(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# %%
new=newdf[["TranslatedIngredients","CookTimeInMins"]].copy()
new[new.TranslatedIngredients.map(lambda x: x.isascii())]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-b61207d16f31> in <module>
#       1 new=newdf[["TranslatedIngredients","CookTimeInMins"]].copy()
# ----> 2 new[new.TranslatedIngredients.map(lambda x: x.isascii())]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     868
#     869         # mapper is a function
# --> 870         new_values = map_f(values, mapper)
#     871
#     872         return new_values
#
# ...
